# %% [markdown]
# # Data Science Intern @Lets Grow More

# %% [markdown]
# ## Author - Pragati Gupta

# %% [markdown]
# ##### Task 2 : Stock Market Prediction And Forecasting Using Stacked LSTM

# %% [markdown]
# ### --- Importing and Inspecting data

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import os
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import math
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in d:\anaconda\lib\site-packages (2.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\anaconda\lib\site-packages (2.6.0)
# Requirement already satisfied: clang~=5.0 in d:\anaconda\lib\site-packages (from tensorflow) (5.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in d:\anaconda\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in d:\anaconda\lib\site-packages (from tensorflow) (1.41.0)
# Requirement already satisfied: wheel~=0.35 in d:\anaconda\lib\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: absl-py~=0.10 in d:\anaconda\lib\site-packages (from tensorflow) (0.14.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in d:\anaconda\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: termcolor~=1.1.0 in d:\anaconda\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: numpy~=1.19.2 in d:\anaconda\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: astunparse~=1.6.3 in d:\anaconda\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in d:\anaconda\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast==0.4.0 in d:\anaconda\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta~=0.2 in d:\anaconda\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in d:\anaconda\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: keras~=2.6 in d:\anaconda\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: six~=1.15.0 in d:\anaconda\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wrapt~=1.12.1 in d:\anaconda\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: protobuf>=3.9.2 in d:\anaconda\lib\site-packages (from tensorflow) (3.18.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorboard~=2.6 in d:\anaconda\lib\site-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: h5py~=3.1.0 in d:\anaconda\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in d:\anaconda\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\anaconda\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in d:\anaconda\lib\site-packages (from tensorboard~=2.6->tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\anaconda\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\anaconda\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\anaconda\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.12.5)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
#----------------------COLLECT STOCK DATA ----------------------------
df=pd.read_csv('task2-dataset.csv')
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
df1=df.reset_index()['Close']
df1
# Out:
# 0       233.75
# 1       233.25
# 2       234.25
# 3       236.10
# 4       233.30
#          ...
# 2030    118.65
# 2031    117.60
# 2032    120.65
# 2033    120.90
# 2034    121.55
# Name: Close, Length: 2035, dtype: float64

# %%
df1.shape
# Out:
# (2035,)

# %%
plt.plot(df1)
plt.rcParams['figure.figsize'] = [15,7]
plt.title('CLOSING GRAPH OF STOCK-MARKET')
# Out:
# Text(0.5, 1.0, 'CLOSING GRAPH OF STOCK-MARKET')

# %%
#----------because lstm is very sensitive to data we have to apply minmaxscaler------------

scaler = MinMaxScaler(feature_range=(0,1))   # to scale down everything b/w 0 n 1
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))
df1
# Out:
# array([[0.62418301],
#        [0.62214052],
#        [0.62622549],
#        ...,
#        [0.1621732 ],
#        [0.16319444],
#        [0.16584967]])

# %%
#------------------PREPROCESSING : TEST-TRAIN SPLIT ---------------------

train_size = int(len(df1)*0.7)      # taking 70 % data as training data 
test_size = len(df1)-train_size     # rest 30 % as testing data

train_data = df1[0:train_size,:]
test_data = df1[train_size:len(df1),:]

# %%
train_data.shape
# Out:
# (1424, 1)

# %%
test_data.shape
# Out:
# (611, 1)

# %%
# making timesteps to predict the future data ... based on prev days data. 

def select_data(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        dataX.append(dataset[i:(i+time_step), 0])
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
timestep = 200

X_train, y_train = select_data(train_data, timestep)
X_test, y_test = select_data(test_data, timestep)

# %%
X_train, y_train
# Out:
# (array([[0.62418301, 0.62214052, 0.62622549, ..., 0.84497549, 0.8880719 ,
#          0.84763072],
#         [0.62214052, 0.62622549, 0.63378268, ..., 0.8880719 , 0.84763072,
#          0.82945261],
#         [0.62622549, 0.63378268, 0.62234477, ..., 0.84763072, 0.82945261,
#          0.79248366],
#         ...,
#         [0.33047386, 0.32128268, 0.34007353, ..., 0.33415033, 0.33986928,
#          0.34681373],
#         [0.32128268, 0.34007353, 0.3310866 , ..., 0.33986928, 0.34681373,
#          0.3500817 ],
#         [0.34007353, 0.3310866 , 0.31495098, ..., 0.34681373, 0.3500817 ,
#          0.32618464]]),
#  array([0.82945261, 0.79248366, 0.8129085 , ..., 0.3500817 , 0.32618464,
#         0.32271242]))

# %%
X_test, y_test
# Out:
# (array([[0.32148693, 0.32352941, 0.3255719 , ..., 0.16115196, 0.15175654,
#          0.14644608],
#         [0.32352941, 0.3255719 , 0.32638889, ..., 0.15175654, 0.14644608,
#          0.15216503],
#         [0.3255719 , 0.32638889, 0.33496732, ..., 0.14644608, 0.15216503,
#          0.1435866 ],
#         ...,
#         [0.06944444, 0.08088235, 0.07700163, ..., 0.14562908, 0.15236928,
#          0.15400327],
#         [0.08088235, 0.07700163, 0.0684232 , ..., 0.15236928, 0.15400327,
#          0.14971405],
#         [0.07700163, 0.0684232 , 0.06781046, ..., 0.15400327, 0.14971405,
,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50))
model.add(Dropout(0.2))

model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
model.fit(X_train, y_train, validation_data = (X_test, y_test),epochs = 50,batch_size = 32, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 200, 50)           10400
# _________________________________________________________________
# dropout (Dropout)            (None, 200, 50)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 200, 50)           20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200, 50)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 39/39 [==============================] - 10s 183ms/step - loss: 0.0104 - val_loss: 0.0028
# Epoch 2/50
# 39/39 [==============================] - 6s 160ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 3/50
# 39/39 [==============================] - 6s 162ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 4/50
# 39/39 [==============================] - 6s 158ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 5/50
# 39/39 [==============================] - 6s 155ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 6/50
# 39/39 [==============================] - 6s 155ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 7/50
# 39/39 [==============================] - 8s 212ms/step - loss: 0.0017 - val_loss: 8.6903e-04
# Epoch 8/50
# 39/39 [==============================] - 7s 186ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 9/50
# 39/39 [==============================] - 7s 188ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 10/50
# 39/39 [==============================] - 7s 183ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 11/50
# 39/39 [==============================] - 8s 200ms/step - loss: 0.0012 - val_loss: 9.8151e-04
# Epoch 12/50
# 39/39 [==============================] - 7s 191ms/step - loss: 0.0012 - val_loss: 7.4497e-04
# Epoch 13/50
# 39/39 [==============================] - 7s 183ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 14/50
# 39/39 [==============================] - 7s 181ms/step - loss: 0.0014 - val_loss: 9.2272e-04
# Epoch 15/50
# 39/39 [==============================] - 7s 182ms/step - loss: 0.0011 - val_loss: 4.2320e-04
# Epoch 16/50
# 39/39 [==============================] - 7s 184ms/step - loss: 0.0012 - val_loss: 4.1235e-04
# Epoch 17/50
# 39/39 [==============================] - 7s 183ms/step - loss: 0.0012 - val_loss: 6.1678e-04
# Epoch 18/50
# 39/39 [==============================] - 7s 192ms/step - loss: 0.0011 - val_loss: 4.4982e-04
# Epoch 19/50
# 39/39 [==============================] - 7s 184ms/step - loss: 0.0010 - val_loss: 4.8247e-04
# Epoch 20/50
# 39/39 [==============================] - 7s 188ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 21/50
# 39/39 [==============================] - 7s 180ms/step - loss: 0.0011 - val_loss: 9.5387e-04
# Epoch 22/50
# 39/39 [==============================] - 7s 181ms/step - loss: 0.0011 - val_loss: 5.0131e-04
# Epoch 23/50
# 39/39 [==============================] - 7s 193ms/step - loss: 9.4405e-04 - val_loss: 0.0010
# Epoch 24/50
# 39/39 [==============================] - 7s 187ms/step - loss: 9.2367e-04 - val_loss: 0.0012
# Epoch 25/50
# 39/39 [==============================] - 7s 183ms/step - loss: 8.5787e-04 - val_loss: 5.5496e-04
# Epoch 26/50
# 39/39 [==============================] - 7s 183ms/step - loss: 9.5169e-04 - val_loss: 0.0012
# Epoch 27/50
# 39/39 [==============================] - 7s 187ms/step - loss: 9.7904e-04 - val_loss: 3.7110e-04
# Epoch 28/50
# 39/39 [==============================] - 7s 180ms/step - loss: 8.5486e-04 - val_loss: 4.9267e-04
# Epoch 29/50
# 39/39 [==============================] - 7s 183ms/step - loss: 8.9128e-04 - val_loss: 3.3229e-04
# Epoch 30/50
# 39/39 [==============================] - 7s 181ms/step - loss: 8.5490e-04 - val_loss: 3.6970e-04
# Epoch 31/50
# 39/39 [==============================] - 7s 181ms/step - loss: 7.0243e-04 - val_loss: 3.9505e-04
# Epoch 32/50
# 39/39 [==============================] - 7s 184ms/step - loss: 7.6292e-04 - val_loss: 3.8624e-04
# Epoch 33/50
# 39/39 [==============================] - 7s 182ms/step - loss: 7.3279e-04 - val_loss: 2.9724e-04
# Epoch 34/50
# 39/39 [==============================] - 7s 182ms/step - loss: 7.0853e-04 - val_loss: 5.7153e-04
# Epoch 35/50
# 39/39 [==============================] - 8s 195ms/step - loss: 7.4335e-04 - val_loss: 9.9832e-04
# Epoch 36/50
# 39/39 [==============================] - 8s 202ms/step - loss: 7.4413e-04 - val_loss: 2.8809e-04
# Epoch 37/50
# 39/39 [==============================] - 8s 217ms/step - loss: 6.8085e-04 - val_loss: 3.3798e-04
# Epoch 38/50
# 39/39 [==============================] - 8s 198ms/step - loss: 6.8364e-04 - val_loss: 2.9357e-04
# Epoch 39/50
# 39/39 [==============================] - 7s 183ms/step - loss: 7.7097e-04 - val_loss: 2.7329e-04
# Epoch 40/50
# 39/39 [==============================] - 7s 180ms/step - loss: 6.4644e-04 - val_loss: 3.2355e-04
# Epoch 41/50
# 39/39 [==============================] - 7s 175ms/step - loss: 6.5732e-04 - val_loss: 3.1595e-04
# Epoch 42/50
# 39/39 [==============================] - 7s 173ms/step - loss: 6.2671e-04 - val_loss: 2.6762e-04
# Epoch 43/50
# 39/39 [==============================] - 7s 174ms/step - loss: 6.0958e-04 - val_loss: 2.7065e-04
# Epoch 44/50
# 39/39 [==============================] - 7s 177ms/step - loss: 5.8486e-04 - val_loss: 2.5671e-04
# Epoch 45/50
# 39/39 [==============================] - 7s 175ms/step - loss: 5.2397e-04 - val_loss: 4.3761e-04
# Epoch 46/50
# 39/39 [==============================] - 7s 190ms/step - loss: 5.5577e-04 - val_loss: 4.8413e-04
# Epoch 47/50
# 39/39 [==============================] - 7s 183ms/step - loss: 5.6863e-04 - val_loss: 3.2076e-04
# Epoch 48/50
# 39/39 [==============================] - 7s 184ms/step - loss: 5.9223e-04 - val_loss: 2.3418e-04
# Epoch 49/50
# 39/39 [==============================] - 7s 173ms/step - loss: 6.0271e-04 - val_loss: 3.4862e-04
# Epoch 50/50
# 39/39 [==============================] - 7s 176ms/step - loss: 5.7553e-04 - val_loss: 2.4597e-04

# %%
#------------DOING PREDICTIONS --------------

train_predict=model.predict(X_train)       # output for train dataset
test_predict=model.predict(X_test)        # output for test dataset

#----------------- BACK TO ORIGINAL DATA ------------------
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
train_predict
# Out:
# array([[284.32922],
#        [284.57153],
#        [281.9722 ],
#        ...,
#        [161.47708],
#        [162.33784],
#        [162.31953]], dtype=float32)

# %%
test_predict
# Out:
# array([[116.34718 ],
#        [117.04115 ],
#        [117.10385 ],
#        [116.39116 ],
#        [115.50063 ],
#        [115.319984],
#        [115.872116],
#        [117.187   ],
#        [119.11834 ],
#        [120.53017 ],
#        [120.145615],
#        [119.21065 ],
#        [118.37934 ],
#        [117.53012 ],
#        [117.20153 ],
#        [117.19407 ],
#        [117.562904],
#        [118.16304 ],
#        [118.77759 ],
#        [119.35419 ],
#        [119.50132 ],
#        [119.77754 ],
#        [119.56969 ],
#        [118.3589  ],
#        [116.859856],
#        [116.027824],
#        [114.75262 ],
#        [112.95214 ],
#        [110.85634 ],
#        [107.68966 ],
#        [103.92584 ],
#        [100.155655],
#        [ 96.77698 ],
#        [ 99.96197 ],
#        [ 99.92119 ],
#        [100.14247 ],
#        [100.41937 ],
#        [100.49623 ],
#        [100.49759 ],
#        [100.311295],
#        [100.60648 ],
#        [101.14589 ],
#        [101.67845 ],
#        [102.23564 ],
#        [101.93448 ],
#        [100.71604 ],
#        [ 98.611015],
#        [ 96.145096],
#        [ 93.806335],
#        [ 91.93607 ],
#        [ 90.55323 ],
#        [ 89.62691 ],
#        [ 89.366295],
#        [ 89.77664 ],
#        [ 91.21949 ],
#        [ 93.08364 ],
#        [ 95.029175],
#        [ 96.86967 ],
#        [ 98.34033 ],
#        [ 98.8068  ],
#        [ 98.465775],
#        [ 97.86965 ],
#        [ 96.83036 ],
#        [ 95.4291  ],
#        [ 94.02985 ],
#        [ 92.94764 ],
#        [ 92.003975],
#        [ 90.71499 ],
#        [ 89.159904],
#        [ 87.811485],
#        [ 86.61547 ],
#        [ 85.93977 ],
#        [ 86.27636 ],
#        [ 87.79069 ],
#        [ 90.17956 ],
#        [ 92.63859 ],
#        [ 94.64075 ],
#        [ 95.94548 ],
#        [ 96.66909 ],
#        [ 97.174255],
#        [ 97.41121 ],
#        [ 97.75053 ],
#        [ 98.08965 ],
#        [ 98.08726 ],
#        [ 97.74147 ],
#        [ 97.0662  ],
#        [ 96.44841 ],
#        [ 96.24245 ],
#        [ 96.49972 ],
#        [ 97.13844 ],
#        [ 98.15966 ],
#        [ 99.48052 ],
#        [100.878204],
#        [101.809204],
#        [102.28161 ],
#        [102.2463  ],
#        [101.82307 ],
#        [101.098915],
#        [100.63644 ],
#        [100.56342 ],
#        [100.68819 ],
#        [101.14079 ],
#        [102.32199 ],
#        [103.66885 ],
#        [104.64312 ],
#        [104.670296],
#        [103.77677 ],
#        [102.0492  ],
#        [ 99.925934],
#        [ 97.795364],
#        [ 96.32783 ],
#        [ 95.62401 ],
#        [ 95.67436 ],
#        [ 96.02891 ],
#        [ 96.45562 ],
#        [ 96.86953 ],
#        [ 97.13032 ],
#        [ 97.18593 ],
#        [ 97.30474 ],
#        [ 97.450035],
#        [ 98.01686 ],
#        [ 98.79928 ],
#        [ 98.95916 ],
#        [ 98.44806 ],
#        [ 97.21589 ],
#        [ 95.06045 ],
#        [ 92.73713 ],
#        [ 90.753204],
#        [ 89.4403  ],
#        [ 88.61508 ],
#        [ 88.08613 ],
#        [ 87.63165 ],
#        [ 88.17132 ],
#        [ 89.71962 ],
#        [ 91.71793 ],
#        [ 93.410484],
#        [ 95.3546  ],
#        [ 96.50718 ],
#        [ 96.84542 ],
#        [ 96.45794 ],
#        [ 95.30132 ],
#        [ 93.32176 ],
#        [ 90.98381 ],
#        [ 89.366646],
#        [ 89.113464],
#        [ 89.92023 ],
#        [ 91.335236],
#        [ 93.02257 ],
#        [ 94.71826 ],
#        [ 96.28654 ],
#        [ 97.58574 ],
#        [ 99.31124 ],
#        [101.27375 ],
#        [103.08154 ],
#        [104.36687 ],
#        [105.14531 ],
#        [105.29809 ],
#        [104.9556  ],
#        [104.37931 ],
#        [103.72578 ],
#        [103.00088 ],
#        [102.384285],
#        [101.74372 ],
#        [101.42729 ],
#        [101.97226 ],
#        [103.50998 ],
#        [105.71101 ],
#        [108.08359 ],
#        [109.9357  ],
#        [110.6013  ],
#        [110.12857 ],
#        [109.25553 ],
#        [108.44137 ],
#        [107.90543 ],
#        [108.01558 ],
#        [108.620705],
#        [109.58326 ],
#        [110.90388 ],
#        [112.25091 ],
#        [113.31804 ],
#        [113.94302 ],
#        [114.06987 ],
#        [113.67666 ],
#        [112.75511 ],
#        [111.67313 ],
#        [111.143814],
#        [111.28474 ],
#        [111.83765 ],
#        [112.415764],
#        [112.9867  ],
#        [113.41666 ],
#        [113.44073 ],
#        [113.13047 ],
#        [112.601166],
#        [111.71335 ],
#        [111.5287  ],
#        [112.165634],
#        [113.626465],
#        [115.461365],
#        [117.11665 ],
#        [118.50031 ],
#        [119.961105],
#        [121.37881 ],
#        [122.961205],
#        [124.98167 ],
#        [126.48233 ],
#        [126.89571 ],
#        [126.46575 ],
#        [125.44164 ],
#        [124.26263 ],
#        [123.32829 ],
#        [122.70293 ],
#        [122.395775],
#        [122.9064  ],
#        [123.80122 ],
#        [124.73623 ],
#        [125.640465],
#        [126.40952 ],
#        [127.20954 ],
#        [127.82929 ],
#        [128.24646 ],
#        [128.45026 ],
#        [128.51677 ],
#        [128.92262 ],
#        [129.70372 ],
#        [130.2634  ],
#        [130.88109 ],
#        [131.30763 ],
#        [131.59601 ],
#        [131.23119 ],
#        [130.06805 ],
#        [128.21141 ],
#        [126.03921 ],
#        [123.628975],
#        [121.57449 ],
#        [120.35605 ],
#        [120.071686],
#        [120.66149 ],
#        [121.53731 ],
#        [121.98502 ],
#        [122.140495],
#        [122.39248 ],
#        [122.52612 ],
#        [122.43616 ],
#        [122.320114],
#        [122.329506],
#        [122.713875],
#        [123.58652 ],
#        [124.608086],
#        [125.55274 ],
#        [125.66639 ],
#        [124.90352 ],
#        [123.69583 ],
#        [122.544235],
#        [121.38337 ],
#        [119.978096],
#        [118.55949 ],
#        [117.43554 ],
#        [116.59072 ],
#        [115.969925],
#        [115.6014  ],
#        [114.80314 ],
#        [113.850555],
#        [112.47572 ],
#        [111.08857 ],
#        [110.12674 ],
#        [110.04525 ],
#        [110.46932 ],
#        [111.234634],
#        [111.880264],
#        [112.30975 ],
#        [112.4216  ],
#        [112.52459 ],
#        [112.99294 ],
#        [113.95632 ],
#        [115.011635],
#        [115.71194 ],
#        [116.036446],
#        [116.27485 ],
#        [116.54677 ],
#        [116.69356 ],
#        [117.08101 ]], dtype=float32)

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 149.0843361153433

# %%
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 103.23435854480427

# %%
t = timestep

p1 = np.empty_like(df1)       #train-pred-plot
p1[:,:] =np.nan
p1[t : len(train_predict)+t , : ] =  train_predict

# %%
p2 = np.empty_like(df1)       #test-pred-plot
p2[:,:] =np.nan
p2[ len(train_predict)+ t*2 + 1 : len(df1) -1 , : ] =  test_predict

# %%
from matplotlib.pyplot import figure
plt.plot(scaler.inverse_transform(df1) , color = 'red', label = 'Real Stock Price')
plt.plot(p1 , color = 'blue', label = 'Predicted Stock Price 1 - training ')
plt.plot(p2 , color = 'green', label = 'Predicted Stock Price 2 - testing ')

plt.rcParams['figure.figsize'] = [15,7]
plt.legend()
plt.show()
